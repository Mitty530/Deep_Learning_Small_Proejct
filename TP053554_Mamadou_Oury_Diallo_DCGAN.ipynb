# %%
from numpy import expand_dims, zeros, ones, vstack
from numpy.random import randn, randint
from keras.datasets.cifar10 import load_data
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Dense, Reshape, Flatten, Conv2D, Conv2DTranspose
from keras.layers import LeakyReLU, Dropout
from matplotlib import pyplot as plt

# %%
# loading the dataset
(X_train, y_train),(X_test, y_test) = load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# 170508288/170498071 [==============================] - 6s 0us/step

# %%
print('X_train shape: ',X_train.shape)
print('y_train shape: ',y_train.shape)
print('X_test shape: ',X_test.shape)
print('y_train shape: ',y_test.shape)
# Out:
# X_train shape:  (50000, 32, 32, 3)
# y_train shape:  (50000, 1)
# X_test shape:  (10000, 32, 32, 3)
# y_train shape:  (10000, 1)

# %%
# plot images from the training dataset
for i in range(49):
	plt.subplot(7, 7, 1 + i)
	plt.axis('off')
	plt.imshow(X_train[i])
plt.show()

# %%
from keras.utils.vis_utils import plot_model

# define the standalone discriminator model
def define_discriminator(in_shape=(32,32,3)):
  model = Sequential()
  model.add(Conv2D(64, (3,3), padding='same', input_shape=in_shape))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Conv2D(128, (3,3), strides=(2,2), padding='same'))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Conv2D(128, (3,3), strides=(2,2), padding='same'))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Conv2D(256, (3,3), strides=(2,2), padding='same'))
  model.add(LeakyReLU(alpha=0.2))
  model.add(Flatten())
  model.add(Dropout(0.4))
  model.add(Dense(1, activation='sigmoid'))
  opt = Adam(lr=0.0002, beta_1=0.5)
  model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
  return model

model = define_discriminator()
model.summary()
plot_model(model, to_file='discriminator_plot.png', show_shapes=True, show_layer_names=True)

# %%
# define the standalone generator model
def define_generator(latent_dim):
	model = Sequential()
	n_nodes = 256 * 4 * 4
	model.add(Dense(n_nodes, input_dim=latent_dim))
	model.add(LeakyReLU(alpha=0.2))
	model.add(Reshape((4, 4, 256)))
	model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
	model.add(LeakyReLU(alpha=0.2))
	model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
	model.add(LeakyReLU(alpha=0.2))
	model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
	model.add(LeakyReLU(alpha=0.2))
	model.add(Conv2D(3, (3,3), activation='tanh', padding='same'))
	return model

# %%
# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
	x_input = randn(latent_dim * n_samples)
	x_input = x_input.reshape(n_samples, latent_dim)
	return x_input

# %%
# define the combined generator and discriminator model, for updating the generator
def define_gan(g_model, d_model):
	d_model.trainable = False
	model = Sequential()
	model.add(g_model)
	model.add(d_model)
	opt = Adam(lr=0.0002, beta_1=0.5)
	model.compile(loss='binary_crossentropy', optimizer=opt)
	return model

# %%
# size of the latent space
latent_dim = 100
d_model = define_discriminator()
g_model = define_generator(latent_dim)
gan_model = define_gan(g_model, d_model)
gan_model.summary()
plot_model(gan_model, to_file='gan_plot.png', show_shapes=True, show_layer_names=True)

# %%
# load and prepare cifar10 training images
def load_real_samples():
	(trainX, _), (_, _) = load_data()
	X = trainX.astype('float32')
	X = (X - 127.5) / 127.5
	return X

# %%
# select real samples
def generate_real_samples(dataset, n_samples):
	ix = randint(0, dataset.shape[0], n_samples)
	X = dataset[ix]
	y = ones((n_samples, 1))
	return X, y

# %%
# use the generator to generate n fake examples, with class labels
def generate_fake_samples(g_model, latent_dim, n_samples):
	x_input = generate_latent_points(latent_dim, n_samples)
	X = g_model.predict(x_input)
	y = zeros((n_samples, 1))
	return X, y

# %%
# create and save a plot of generated images
def save_plot(examples, epoch, n=7):
	examples = (examples + 1) / 2.0
	for i in range(n * n):
		plt.subplot(n, n, 1 + i)
		plt.axis('off')
		plt.imshow(examples[i])
	filename = 'generated_plot_e%03d.png' % (epoch+1)
	plt.savefig(filename)
	plt.close()

# %%
# evaluate the discriminator, plot generated images, save generator model
def summarize_performance(epoch, g_model, d_model, dataset, latent_dim, n_samples=150):
	X_real, y_real = generate_real_samples(dataset, n_samples)
	_, acc_real = d_model.evaluate(X_real, y_real, verbose=0)
	x_fake, y_fake = generate_fake_samples(g_model, latent_dim, n_samples)
	_, acc_fake = d_model.evaluate(x_fake, y_fake, verbose=0)
	print('>Accuracy real: %.0f%%, fake: %.0f%%' % (acc_real*100, acc_fake*100))
	save_plot(x_fake, epoch)
	filename = 'generator_model_%03d.h5' % (epoch+1)
	g_model.save(filename)

# %%
# train the generator and discriminator
def train(g_model, d_model, gan_model, dataset, latent_dim, n_epochs=1, n_batch=128):
	bat_per_epo = int(dataset.shape[0] / n_batch)
	half_batch = int(n_batch / 2)
	for i in range(n_epochs):
		for j in range(bat_per_epo):
			X_real, y_real = generate_real_samples(dataset, half_batch)
			d_loss1, _ = d_model.train_on_batch(X_real, y_real)
			X_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
			d_loss2, _ = d_model.train_on_batch(X_fake, y_fake)
			X_gan = generate_latent_points(latent_dim, n_batch)
			y_gan = ones((n_batch, 1))
			g_loss = gan_model.train_on_batch(X_gan, y_gan)
			print('>%d, %d/%d, d1=%.3f, d2=%.3f g=%.3f' %
				(i+1, j+1, bat_per_epo, d_loss1, d_loss2, g_loss))
	
			summarize_performance(i, g_model, d_model, dataset, latent_dim)

# %%
latent_dim = 100
d_model = define_discriminator()
g_model = define_generator(latent_dim)
gan_model = define_gan(g_model, d_model)
dataset = load_real_samples()
train(g_model, d_model, gan_model, dataset, latent_dim)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# >1, 1/390, d1=0.703, d2=0.695 g=0.692
# >Accuracy real: 100%, fake: 0%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 2/390, d1=0.631, d2=0.698 g=0.689
# >Accuracy real: 100%, fake: 0%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 3/390, d1=0.567, d2=0.705 g=0.682
# >Accuracy real: 100%, fake: 0%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 4/390, d1=0.492, d2=0.723 g=0.665
# >Accuracy real: 100%, fake: 0%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 5/390, d1=0.398, d2=0.765 g=0.635
# >Accuracy real: 100%, fake: 0%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 6/390, d1=0.276, d2=0.836 g=0.599
# >Accuracy real: 100%, fake: 0%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 7/390, d1=0.198, d2=0.897 g=0.590
# >Accuracy real: 100%, fake: 0%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 8/390, d1=0.151, d2=0.868 g=0.647
# >Accuracy real: 100%, fake: 0%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 9/390, d1=0.142, d2=0.734 g=0.785
# >Accuracy real: 100%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 10/390, d1=0.135, d2=0.593 g=0.948
# >Accuracy real: 96%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 11/390, d1=0.133, d2=0.535 g=0.993
# >Accuracy real: 96%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 12/390, d1=0.156, d2=0.562 g=0.908
# >Accuracy real: 98%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 13/390, d1=0.064, d2=0.596 g=0.849
# >Accuracy real: 99%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 14/390, d1=0.075, d2=0.651 g=0.801
# >Accuracy real: 95%, fake: 0%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 15/390, d1=0.070, d2=0.766 g=0.748
# >Accuracy real: 97%, fake: 0%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 16/390, d1=0.046, d2=0.929 g=0.667
# >Accuracy real: 96%, fake: 0%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 17/390, d1=0.057, d2=0.984 g=0.663
# >Accuracy real: 97%, fake: 0%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 18/390, d1=0.100, d2=0.869 g=0.776
# >Accuracy real: 99%, fake: 0%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 19/390, d1=0.202, d2=0.699 g=0.940
# >Accuracy real: 98%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 20/390, d1=0.154, d2=0.582 g=1.037
# >Accuracy real: 94%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 21/390, d1=0.142, d2=0.591 g=1.005
# >Accuracy real: 94%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 22/390, d1=0.168, d2=0.621 g=0.907
# >Accuracy real: 89%, fake: 42%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 23/390, d1=0.123, d2=0.730 g=0.798
# >Accuracy real: 91%, fake: 0%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 24/390, d1=0.125, d2=1.013 g=0.590
# >Accuracy real: 98%, fake: 0%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 25/390, d1=0.104, d2=1.269 g=0.549
# >Accuracy real: 98%, fake: 0%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 26/390, d1=0.087, d2=1.118 g=0.682
# >Accuracy real: 91%, fake: 0%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 27/390, d1=0.191, d2=0.807 g=0.860
# >Accuracy real: 95%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 28/390, d1=0.167, d2=0.580 g=1.078
# >Accuracy real: 98%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 29/390, d1=0.135, d2=0.455 g=1.227
# >Accuracy real: 97%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 30/390, d1=0.135, d2=0.404 g=1.292
# >Accuracy real: 99%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 31/390, d1=0.064, d2=0.399 g=1.269
# >Accuracy real: 100%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 32/390, d1=0.055, d2=0.424 g=1.170
# >Accuracy real: 100%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 33/390, d1=0.046, d2=0.487 g=1.021
# >Accuracy real: 100%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 34/390, d1=0.020, d2=0.552 g=0.904
# >Accuracy real: 100%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 35/390, d1=0.017, d2=0.591 g=0.858
# >Accuracy real: 100%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 36/390, d1=0.026, d2=0.598 g=0.861
# >Accuracy real: 100%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 37/390, d1=0.012, d2=0.589 g=0.889
# >Accuracy real: 100%, fake: 93%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 38/390, d1=0.016, d2=0.582 g=0.952
# >Accuracy real: 100%, fake: 97%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 39/390, d1=0.016, d2=0.514 g=1.118
# >Accuracy real: 100%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 40/390, d1=0.023, d2=0.373 g=1.382
# >Accuracy real: 100%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 41/390, d1=0.053, d2=0.293 g=1.505
# >Accuracy real: 100%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 42/390, d1=0.017, d2=0.287 g=1.529
# >Accuracy real: 100%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 43/390, d1=0.034, d2=0.285 g=1.514
# >Accuracy real: 100%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 44/390, d1=0.005, d2=0.275 g=1.537
# >Accuracy real: 100%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 45/390, d1=0.012, d2=0.261 g=1.591
# >Accuracy real: 100%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 46/390, d1=0.004, d2=0.247 g=1.693
# >Accuracy real: 100%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 47/390, d1=0.004, d2=0.247 g=1.825
# >Accuracy real: 100%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 48/390, d1=0.014, d2=0.355 g=2.382
# >Accuracy real: 100%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 49/390, d1=0.061, d2=0.140 g=3.223
# >Accuracy real: 77%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 50/390, d1=0.415, d2=0.596 g=1.115
# >Accuracy real: 100%, fake: 1%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 51/390, d1=0.001, d2=1.927 g=2.119
# >Accuracy real: 99%, fake: 49%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 52/390, d1=0.023, d2=0.082 g=4.727
# >Accuracy real: 84%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 53/390, d1=0.699, d2=0.428 g=2.252
# >Accuracy real: 99%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 54/390, d1=0.048, d2=0.229 g=4.237
# >Accuracy real: 90%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 55/390, d1=0.152, d2=0.031 g=4.268
# >Accuracy real: 83%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 56/390, d1=0.348, d2=0.531 g=4.512
# >Accuracy real: 85%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 57/390, d1=0.355, d2=0.028 g=4.096
# >Accuracy real: 77%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 58/390, d1=0.327, d2=0.149 g=3.032
# >Accuracy real: 87%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 59/390, d1=0.214, d2=0.165 g=3.567
# >Accuracy real: 89%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 60/390, d1=0.133, d2=0.063 g=3.830
# >Accuracy real: 91%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 61/390, d1=0.176, d2=0.187 g=4.416
# >Accuracy real: 85%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 62/390, d1=0.130, d2=0.082 g=4.097
# >Accuracy real: 86%, fake: 51%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 63/390, d1=0.221, d2=0.611 g=4.732
# >Accuracy real: 93%, fake: 90%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 64/390, d1=0.271, d2=0.052 g=4.015
# >Accuracy real: 93%, fake: 35%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 65/390, d1=0.185, d2=0.943 g=3.750
# >Accuracy real: 87%, fake: 43%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 66/390, d1=0.202, d2=0.332 g=3.085
# >Accuracy real: 87%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 67/390, d1=0.303, d2=0.485 g=2.676
# >Accuracy real: 73%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 68/390, d1=0.707, d2=0.678 g=1.864
# >Accuracy real: 97%, fake: 67%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 69/390, d1=0.055, d2=0.347 g=3.143
# >Accuracy real: 88%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 70/390, d1=0.299, d2=0.139 g=3.261
# >Accuracy real: 94%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 71/390, d1=0.159, d2=0.154 g=4.011
# >Accuracy real: 95%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 72/390, d1=0.161, d2=0.065 g=4.415
# >Accuracy real: 99%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 73/390, d1=0.087, d2=0.041 g=4.882
# >Accuracy real: 95%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 74/390, d1=0.042, d2=0.021 g=4.988
# >Accuracy real: 99%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 75/390, d1=0.064, d2=0.031 g=4.547
# >Accuracy real: 99%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 76/390, d1=0.026, d2=0.116 g=4.784
# >Accuracy real: 96%, fake: 43%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 77/390, d1=0.029, d2=0.724 g=3.431
# >Accuracy real: 85%, fake: 52%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 78/390, d1=0.393, d2=0.398 g=4.394
# >Accuracy real: 86%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 79/390, d1=0.281, d2=0.029 g=4.480
# >Accuracy real: 87%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 80/390, d1=0.267, d2=0.207 g=4.524
# >Accuracy real: 83%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 81/390, d1=0.362, d2=0.229 g=5.673
# >Accuracy real: 79%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 82/390, d1=0.411, d2=0.017 g=4.670
# >Accuracy real: 78%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 83/390, d1=0.377, d2=0.165 g=4.337
# >Accuracy real: 77%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 84/390, d1=0.215, d2=0.068 g=4.646
# >Accuracy real: 77%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 85/390, d1=0.393, d2=0.804 g=9.111
# >Accuracy real: 63%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 86/390, d1=1.067, d2=0.001 g=9.777
# >Accuracy real: 70%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 87/390, d1=1.071, d2=0.003 g=5.229
# >Accuracy real: 82%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 88/390, d1=0.579, d2=0.039 g=3.513
# >Accuracy real: 87%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 89/390, d1=0.296, d2=0.076 g=3.304
# >Accuracy real: 90%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 90/390, d1=0.298, d2=0.060 g=3.534
# >Accuracy real: 89%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 91/390, d1=0.078, d2=0.033 g=3.931
# >Accuracy real: 90%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 92/390, d1=0.262, d2=0.030 g=4.034
# >Accuracy real: 86%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 93/390, d1=0.128, d2=0.028 g=3.861
# >Accuracy real: 87%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 94/390, d1=0.205, d2=0.033 g=3.930
# >Accuracy real: 89%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 95/390, d1=0.177, d2=0.036 g=4.200
# >Accuracy real: 93%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 96/390, d1=0.098, d2=0.017 g=4.376
# >Accuracy real: 93%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 97/390, d1=0.131, d2=0.020 g=4.442
# >Accuracy real: 96%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 98/390, d1=0.082, d2=0.016 g=4.677
# >Accuracy real: 93%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 99/390, d1=0.068, d2=0.011 g=4.959
# >Accuracy real: 95%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 100/390, d1=0.108, d2=0.012 g=5.126
# >Accuracy real: 98%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 101/390, d1=0.050, d2=0.016 g=5.357
# >Accuracy real: 97%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 102/390, d1=0.058, d2=0.014 g=5.673
# >Accuracy real: 97%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 103/390, d1=0.041, d2=0.022 g=5.981
# >Accuracy real: 98%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 104/390, d1=0.084, d2=0.004 g=6.104
# >Accuracy real: 99%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 105/390, d1=0.072, d2=0.153 g=6.216
# >Accuracy real: 98%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 106/390, d1=0.031, d2=0.004 g=6.108
# >Accuracy real: 99%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 107/390, d1=0.056, d2=0.007 g=6.535
# >Accuracy real: 99%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 108/390, d1=0.041, d2=0.053 g=6.972
# >Accuracy real: 99%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 109/390, d1=0.051, d2=0.066 g=8.107
# >Accuracy real: 98%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 110/390, d1=0.011, d2=0.079 g=8.727
# >Accuracy real: 98%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 111/390, d1=0.043, d2=0.029 g=9.293
# >Accuracy real: 99%, fake: 97%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 112/390, d1=0.098, d2=0.024 g=9.179
# >Accuracy real: 99%, fake: 95%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 113/390, d1=0.055, d2=0.417 g=6.646
# >Accuracy real: 100%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 114/390, d1=0.024, d2=0.037 g=6.861
# >Accuracy real: 99%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 115/390, d1=0.060, d2=0.120 g=5.288
# >Accuracy real: 98%, fake: 97%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 116/390, d1=0.101, d2=0.014 g=5.348
# >Accuracy real: 99%, fake: 97%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 117/390, d1=0.057, d2=0.038 g=4.849
# >Accuracy real: 97%, fake: 95%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 118/390, d1=0.041, d2=0.283 g=5.610
# >Accuracy real: 99%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 119/390, d1=0.125, d2=0.034 g=5.993
# >Accuracy real: 99%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 120/390, d1=0.063, d2=0.101 g=5.354
# >Accuracy real: 96%, fake: 8%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 121/390, d1=0.031, d2=1.256 g=8.661
# >Accuracy real: 78%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 122/390, d1=0.505, d2=0.033 g=11.481
# >Accuracy real: 69%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 123/390, d1=0.797, d2=0.004 g=6.636
# >Accuracy real: 81%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 124/390, d1=0.238, d2=0.278 g=2.565
# >Accuracy real: 87%, fake: 97%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 125/390, d1=0.376, d2=0.376 g=2.642
# >Accuracy real: 85%, fake: 96%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 126/390, d1=0.297, d2=0.155 g=2.856
# >Accuracy real: 80%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 127/390, d1=0.346, d2=0.256 g=3.056
# >Accuracy real: 83%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 128/390, d1=0.309, d2=0.103 g=2.908
# >Accuracy real: 81%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 129/390, d1=0.234, d2=0.140 g=3.105
# >Accuracy real: 70%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 130/390, d1=0.329, d2=0.136 g=2.956
# >Accuracy real: 85%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 131/390, d1=0.440, d2=0.302 g=3.174
# >Accuracy real: 83%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 132/390, d1=0.355, d2=0.136 g=3.408
# >Accuracy real: 75%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 133/390, d1=0.313, d2=0.087 g=3.436
# >Accuracy real: 79%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 134/390, d1=0.326, d2=0.189 g=3.280
# >Accuracy real: 86%, fake: 97%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 135/390, d1=0.440, d2=0.175 g=3.268
# >Accuracy real: 86%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 136/390, d1=0.299, d2=0.086 g=3.315
# >Accuracy real: 81%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 137/390, d1=0.350, d2=0.111 g=3.208
# >Accuracy real: 82%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 138/390, d1=0.236, d2=0.085 g=3.324
# >Accuracy real: 83%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 139/390, d1=0.285, d2=0.121 g=3.232
# >Accuracy real: 88%, fake: 97%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 140/390, d1=0.255, d2=0.174 g=3.571
# >Accuracy real: 87%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 141/390, d1=0.346, d2=0.095 g=3.333
# >Accuracy real: 85%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 142/390, d1=0.307, d2=0.117 g=3.335
# >Accuracy real: 87%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 143/390, d1=0.198, d2=0.084 g=3.445
# >Accuracy real: 87%, fake: 96%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 144/390, d1=0.243, d2=0.475 g=3.934
# >Accuracy real: 83%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 145/390, d1=0.415, d2=0.056 g=3.646
# >Accuracy real: 83%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 146/390, d1=0.290, d2=0.176 g=3.539
# >Accuracy real: 83%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 147/390, d1=0.278, d2=0.160 g=3.584
# >Accuracy real: 82%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 148/390, d1=0.350, d2=0.085 g=3.791
# >Accuracy real: 80%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 149/390, d1=0.254, d2=0.091 g=3.802
# >Accuracy real: 87%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 150/390, d1=0.236, d2=0.105 g=3.765
# >Accuracy real: 91%, fake: 97%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 151/390, d1=0.098, d2=0.121 g=4.279
# >Accuracy real: 87%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 152/390, d1=0.258, d2=0.087 g=4.187
# >Accuracy real: 92%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 153/390, d1=0.251, d2=0.063 g=4.312
# >Accuracy real: 97%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 154/390, d1=0.121, d2=0.109 g=4.235
# >Accuracy real: 95%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 155/390, d1=0.165, d2=0.079 g=4.236
# >Accuracy real: 98%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 156/390, d1=0.111, d2=0.169 g=4.802
# >Accuracy real: 95%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 157/390, d1=0.143, d2=0.067 g=4.520
# >Accuracy real: 93%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 158/390, d1=0.085, d2=0.076 g=4.815
# >Accuracy real: 96%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 159/390, d1=0.176, d2=0.084 g=4.035
# >Accuracy real: 94%, fake: 91%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 160/390, d1=0.138, d2=0.668 g=5.520
# >Accuracy real: 77%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 161/390, d1=0.719, d2=0.090 g=4.377
# >Accuracy real: 63%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 162/390, d1=0.804, d2=0.133 g=2.556
# >Accuracy real: 80%, fake: 97%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 163/390, d1=0.420, d2=0.953 g=2.462
# >Accuracy real: 75%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 164/390, d1=0.311, d2=0.157 g=2.836
# >Accuracy real: 71%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 165/390, d1=0.718, d2=0.243 g=2.573
# >Accuracy real: 79%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 166/390, d1=0.423, d2=0.166 g=2.533
# >Accuracy real: 82%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 167/390, d1=0.260, d2=0.309 g=2.638
# >Accuracy real: 88%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 168/390, d1=0.316, d2=0.193 g=2.620
# >Accuracy real: 85%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 169/390, d1=0.351, d2=0.179 g=2.663
# >Accuracy real: 89%, fake: 97%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 170/390, d1=0.237, d2=0.184 g=2.778
# >Accuracy real: 91%, fake: 96%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 171/390, d1=0.276, d2=0.191 g=2.450
# >Accuracy real: 95%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 172/390, d1=0.190, d2=0.201 g=2.751
# >Accuracy real: 94%, fake: 96%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 173/390, d1=0.145, d2=0.124 g=3.049
# >Accuracy real: 94%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 174/390, d1=0.138, d2=0.169 g=2.863
# >Accuracy real: 93%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 175/390, d1=0.131, d2=0.262 g=2.597
# >Accuracy real: 91%, fake: 96%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 176/390, d1=0.159, d2=0.485 g=2.370
# >Accuracy real: 81%, fake: 94%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 177/390, d1=0.203, d2=0.298 g=2.710
# >Accuracy real: 79%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 178/390, d1=0.369, d2=0.187 g=3.953
# >Accuracy real: 77%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 179/390, d1=0.449, d2=0.102 g=3.448
# >Accuracy real: 77%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 180/390, d1=0.307, d2=0.253 g=2.633
# >Accuracy real: 87%, fake: 97%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 181/390, d1=0.367, d2=0.359 g=2.726
# >Accuracy real: 83%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 182/390, d1=0.283, d2=0.244 g=2.548
# >Accuracy real: 76%, fake: 97%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 183/390, d1=0.523, d2=0.260 g=2.055
# >Accuracy real: 84%, fake: 93%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 184/390, d1=0.398, d2=0.396 g=2.163
# >Accuracy real: 81%, fake: 97%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 185/390, d1=0.292, d2=0.225 g=2.636
# >Accuracy real: 77%, fake: 97%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 186/390, d1=0.313, d2=0.175 g=2.527
# >Accuracy real: 75%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 187/390, d1=0.295, d2=0.202 g=2.146
# >Accuracy real: 78%, fake: 96%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 188/390, d1=0.412, d2=0.411 g=2.156
# >Accuracy real: 83%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 189/390, d1=0.364, d2=0.144 g=2.288
# >Accuracy real: 79%, fake: 95%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 190/390, d1=0.275, d2=0.248 g=2.356
# >Accuracy real: 89%, fake: 95%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 191/390, d1=0.238, d2=0.353 g=2.411
# >Accuracy real: 86%, fake: 94%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 192/390, d1=0.263, d2=0.488 g=2.491
# >Accuracy real: 89%, fake: 97%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 193/390, d1=0.268, d2=0.215 g=2.478
# >Accuracy real: 93%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 194/390, d1=0.233, d2=0.250 g=2.532
# >Accuracy real: 95%, fake: 97%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 195/390, d1=0.126, d2=0.299 g=2.656
# >Accuracy real: 89%, fake: 94%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 196/390, d1=0.098, d2=0.152 g=2.963
# >Accuracy real: 89%, fake: 96%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 197/390, d1=0.318, d2=0.259 g=2.827
# >Accuracy real: 93%, fake: 95%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 198/390, d1=0.231, d2=0.194 g=2.892
# >Accuracy real: 89%, fake: 93%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 199/390, d1=0.146, d2=0.253 g=2.487
# >Accuracy real: 89%, fake: 90%
# ...
# >1, 325/390, d1=0.233, d2=0.334 g=1.693
# >Accuracy real: 91%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 326/390, d1=0.219, d2=0.290 g=1.792
# >Accuracy real: 90%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 327/390, d1=0.324, d2=0.293 g=1.783
# >Accuracy real: 93%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 328/390, d1=0.250, d2=0.320 g=1.748
# >Accuracy real: 90%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 329/390, d1=0.209, d2=0.285 g=1.789
# >Accuracy real: 85%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 330/390, d1=0.286, d2=0.324 g=1.804
# >Accuracy real: 84%, fake: 97%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 331/390, d1=0.195, d2=0.418 g=1.935
# >Accuracy real: 81%, fake: 81%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 332/390, d1=0.269, d2=0.452 g=1.718
# >Accuracy real: 74%, fake: 59%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 333/390, d1=0.459, d2=0.813 g=1.370
# >Accuracy real: 77%, fake: 49%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 334/390, d1=0.484, d2=1.351 g=1.697
# >Accuracy real: 64%, fake: 54%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 335/390, d1=0.632, d2=0.663 g=2.289
# >Accuracy real: 62%, fake: 89%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 336/390, d1=0.741, d2=0.315 g=2.258
# >Accuracy real: 65%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 337/390, d1=0.487, d2=0.338 g=2.543
# >Accuracy real: 63%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 338/390, d1=0.537, d2=0.200 g=2.512
# >Accuracy real: 71%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 339/390, d1=0.480, d2=0.315 g=2.461
# >Accuracy real: 72%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 340/390, d1=0.516, d2=0.269 g=2.545
# >Accuracy real: 76%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 341/390, d1=0.433, d2=0.254 g=2.527
# >Accuracy real: 71%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 342/390, d1=0.487, d2=0.317 g=2.268
# >Accuracy real: 68%, fake: 90%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 343/390, d1=0.449, d2=0.390 g=2.310
# >Accuracy real: 71%, fake: 92%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 344/390, d1=0.498, d2=0.453 g=2.064
# >Accuracy real: 67%, fake: 92%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 345/390, d1=0.663, d2=0.444 g=1.660
# >Accuracy real: 71%, fake: 67%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 346/390, d1=0.547, d2=0.690 g=1.626
# >Accuracy real: 68%, fake: 53%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 347/390, d1=0.409, d2=0.865 g=1.466
# >Accuracy real: 70%, fake: 51%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 348/390, d1=0.583, d2=0.861 g=1.373
# >Accuracy real: 71%, fake: 63%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 349/390, d1=0.615, d2=0.816 g=1.539
# >Accuracy real: 69%, fake: 75%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 350/390, d1=0.630, d2=0.492 g=1.500
# >Accuracy real: 69%, fake: 79%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 351/390, d1=0.428, d2=0.392 g=1.909
# >Accuracy real: 67%, fake: 89%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 352/390, d1=0.666, d2=0.447 g=1.671
# >Accuracy real: 69%, fake: 85%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 353/390, d1=0.647, d2=0.460 g=1.795
# >Accuracy real: 70%, fake: 87%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 354/390, d1=0.640, d2=0.446 g=2.028
# >Accuracy real: 67%, fake: 87%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 355/390, d1=0.548, d2=0.368 g=1.926
# >Accuracy real: 71%, fake: 95%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 356/390, d1=0.466, d2=0.322 g=1.946
# >Accuracy real: 72%, fake: 94%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 357/390, d1=0.620, d2=0.336 g=1.786
# >Accuracy real: 75%, fake: 91%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 358/390, d1=0.439, d2=0.375 g=1.803
# >Accuracy real: 77%, fake: 93%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 359/390, d1=0.560, d2=0.390 g=1.704
# >Accuracy real: 73%, fake: 93%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 360/390, d1=0.461, d2=0.481 g=1.800
# >Accuracy real: 66%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 361/390, d1=0.548, d2=0.415 g=1.863
# >Accuracy real: 63%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 362/390, d1=0.610, d2=0.414 g=1.856
# >Accuracy real: 73%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 363/390, d1=0.413, d2=0.348 g=1.850
# >Accuracy real: 71%, fake: 95%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 364/390, d1=0.492, d2=0.393 g=1.928
# >Accuracy real: 81%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 365/390, d1=0.413, d2=0.294 g=2.030
# >Accuracy real: 77%, fake: 98%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 366/390, d1=0.419, d2=0.325 g=2.190
# >Accuracy real: 76%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 367/390, d1=0.592, d2=0.298 g=2.092
# >Accuracy real: 92%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 368/390, d1=0.289, d2=0.341 g=2.415
# >Accuracy real: 85%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 369/390, d1=0.348, d2=0.248 g=2.761
# >Accuracy real: 78%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 370/390, d1=0.307, d2=0.156 g=2.805
# >Accuracy real: 80%, fake: 100%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 371/390, d1=0.370, d2=0.206 g=2.310
# >Accuracy real: 84%, fake: 91%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 372/390, d1=0.471, d2=0.442 g=2.491
# >Accuracy real: 81%, fake: 83%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 373/390, d1=0.345, d2=0.326 g=2.672
# >Accuracy real: 74%, fake: 74%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 374/390, d1=0.466, d2=0.601 g=2.517
# >Accuracy real: 66%, fake: 78%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 375/390, d1=0.701, d2=0.665 g=2.496
# >Accuracy real: 59%, fake: 94%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 376/390, d1=0.801, d2=0.350 g=2.552
# >Accuracy real: 48%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 377/390, d1=0.914, d2=0.253 g=2.167
# >Accuracy real: 63%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 378/390, d1=0.722, d2=0.451 g=1.983
# >Accuracy real: 72%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 379/390, d1=0.759, d2=0.364 g=1.866
# >Accuracy real: 65%, fake: 92%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 380/390, d1=0.553, d2=0.545 g=2.119
# >Accuracy real: 63%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 381/390, d1=0.583, d2=0.253 g=1.969
# >Accuracy real: 61%, fake: 99%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 382/390, d1=0.688, d2=0.469 g=1.564
# >Accuracy real: 71%, fake: 77%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 383/390, d1=0.462, d2=0.532 g=1.577
# >Accuracy real: 72%, fake: 60%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 384/390, d1=0.683, d2=0.638 g=1.357
# >Accuracy real: 62%, fake: 55%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 385/390, d1=0.479, d2=0.932 g=1.556
# >Accuracy real: 53%, fake: 65%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 386/390, d1=0.817, d2=0.838 g=1.848
# >Accuracy real: 48%, fake: 75%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 387/390, d1=0.919, d2=0.788 g=1.864
# >Accuracy real: 55%, fake: 84%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 388/390, d1=0.826, d2=0.487 g=1.835
# >Accuracy real: 61%, fake: 83%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 389/390, d1=0.725, d2=0.593 g=1.824
# >Accuracy real: 62%, fake: 88%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >1, 390/390, d1=0.636, d2=0.591 g=1.917
# >Accuracy real: 63%, fake: 87%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from keras.models import load_model
from numpy import asarray

def create_plot(examples, n):
	for i in range(n * n):
		plt.subplot(n, n, 1 + i)
		plt.axis('off')
		plt.imshow(examples[i, :, :])
	plt.show()
 
model = load_model('generator_model_001.h5')
latent_points = generate_latent_points(100, 100)
X = model.predict(latent_points)
X = (X + 1) / 2.0
create_plot(X, 10)

vector = asarray([[0.75 for _ in range(100)]])
X = model.predict(vector)
X = (X + 1) / 2.0
plt.imshow(X[0, :, :])
plt.show()
